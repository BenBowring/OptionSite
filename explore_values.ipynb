# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import datetime as dt
import yfinance as yf
from concurrent.futures import ThreadPoolExecutor

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
from utils.calculations import *
from utils.df_operations import *

# %%
html = requests.get('http://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
soup = BeautifulSoup(html.text, 'lxml')
table = soup.find('table', {'class': 'wikitable sortable'})

# %%
stock_data = pd.read_html(str(table))[0]
names = [name.replace(".", "-") for name in stock_data.Symbol]
name_query = " ".join(names)

# %%
tickers = yf.Tickers(name_query)

# %%
df_info = pd.DataFrame()

for name in names[:5]:
    
    df_info = pd.concat([df_info, pd.DataFrame([tickers.tickers[name].info])])

# %%
df_info
# Out:
#      zip      sector  fullTimeEmployees  \
# 0  95014  Technology             164000
# 0  95014  Technology             164000
# 0  95014  Technology             164000
# 0  95014  Technology             164000
# 0  95014  Technology             164000
#
#                                  longBusinessSummary       city         phone  \
# 0  Apple Inc. designs, manufactures, and markets ...  Cupertino  408 996 1010
# 0  Apple Inc. designs, manufactures, and markets ...  Cupertino  408 996 1010
# 0  Apple Inc. designs, manufactures, and markets ...  Cupertino  408 996 1010
# 0  Apple Inc. designs, manufactures, and markets ...  Cupertino  408 996 1010
# 0  Apple Inc. designs, manufactures, and markets ...  Cupertino  408 996 1010
#
#   state        country companyOfficers                website  ...     bid  \
# 0    CA  United States              []  https://www.apple.com  ...  132.78
# 0    CA  United States              []  https://www.apple.com  ...  132.78
# ...

# %%
pd.DataFrame([tickers.tickers['AAPL'].info])
# Out:
#      zip      sector  fullTimeEmployees  \
# 0  95014  Technology             164000
#
#                                  longBusinessSummary       city         phone  \
# 0  Apple Inc. designs, manufactures, and markets ...  Cupertino  408 996 1010
#
#   state        country companyOfficers                website  ...     bid  \
# 0    CA  United States              []  https://www.apple.com  ...  132.78
#
#   tradeable dividendYield  bidSize  dayHigh  coinMarketCapLink  \
# 0     False        0.0074      900   133.41               None
#
#    regularMarketPrice  preMarketPrice                             logo_url  \
# 0             132.815           130.5  https://logo.clearbit.com/apple.com
#
#    trailingPegRatio
# 0            2.5328
#
# [1 rows x 154 columns]

# %%
def get_all_data(tick):
    
    t_data = tick.info

# %%
import pandas as pd
import pandas_datareader.data as web
import numpy as np

FB = web.YahooOptions('FB')

# %%
FB = web.YahooOptions('FB')
FB.headers = {'User-Agent': 'Firefox'}

# %%
from pandas_datareader import data as pdr

import yfinance as yf
yf.pdr_override()
